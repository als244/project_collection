# %%
import pandas as pd
import numpy as np
import glob
import time
import json
import datetime

# %%
NBA_PLAYBYPLAY_PREF = "./data/nba/stats/playbyplay/20230107/0022200591/"

# %%
play_by_play_df = pd.read_pickle(NBA_PLAYBYPLAY_PREF + "17_26_30.pickle")

# %%
play_by_play_df
# Out:
#      actionNumber        clock              timeActual  period scoreHome  \
# 0               2  PT12M00.00S  2023-01-07T23:11:36.6Z       1         0
# 1               4  PT11M56.00S  2023-01-07T23:11:40.1Z       1         0
# 2               7  PT11M47.00S  2023-01-07T23:11:48.7Z       1         0
# 3               8  PT11M42.00S  2023-01-07T23:11:52.8Z       1         0
# 4              10  PT11M24.00S  2023-01-07T23:12:18.6Z       1         0
# ..            ...          ...                     ...     ...       ...
# 327           392  PT08M47.00S  2023-01-08T00:25:07.0Z       3        65
# 328           393  PT08M44.00S  2023-01-08T00:25:13.8Z       3        67
# 329           394  PT08M44.00S  2023-01-08T00:25:18.0Z       3        67
# 330           396  PT08M44.00S  2023-01-08T00:25:43.3Z       3        68
# 331           397  PT08M34.00S  2023-01-08T00:25:56.4Z       3        68
#
#     scoreAway        teamId teamTricode actionType    subType  ... shotResult  \
# ...
